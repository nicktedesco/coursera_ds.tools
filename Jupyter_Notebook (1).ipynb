# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Nicholas Tedesco__
#
# Data Analyst

# %% [markdown]
# _I am interested in data science because it is an in-demand field. There is a current demand for data scientists, and it looks to be a desirable field to work in._

# %% [markdown]
# ### My code below will solve 1 + 1

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# - this
# - is
# - a
# - list
#
# | This |  is   |
# |------|-------|
# |  a   | table |
#
# 1. this
# 2. is
# 3. another
# 4. list
